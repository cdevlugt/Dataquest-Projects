# %%
#Import packages
import pandas as pd
import matplotlib.pyplot as plt

#set up inline graphing
# %matplotlib inline

#read data
recent_grads = pd.read_csv('recent-grads.csv')
# Out:
# ImportErrorTraceback (most recent call last)
# <ipython-input-23-8a1d02330ebe> in <module>()
#       4
#       5 #scatter matrix
# ----> 6 import pandas.plotting.scatter_matrix
#       7
#       8 #set up inline graphing
#
# ImportError: No module named 'pandas.plotting.scatter_matrix'

# %% [markdown]
# Data set is as:
#
#     Rank - Rank by median earnings (defines order)
#
#     Major_code - Major code.
#
#     Major - Major description.
#
#     Major_category - Category of major.
#
#     Total - Total number of people with major.
#
#     Sample_size - Sample size (unweighted) of full-time.
#
#     Men - Male graduates.
#
#     Women - Female graduates.
#
#     ShareWomen - Women as share of total.
#
#     Employed - Number employed.
#
#     Median - Median salary of full-time, year-round workers.
#
#     Low_wage_jobs - Number in low-wage service jobs.
#
#     Full_time - Number employed 35 hours or more.
#
#     Part_time - Number employed less than 35 hours.

# %%
#data set layout:
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
print(recent_grads.head())
print(recent_grads.tail())
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
recent_grads.describe(include = 'all')
# Out:
#               Rank   Major_code                                     Major  \
# count   173.000000   173.000000                                       173
# unique         NaN          NaN                                       173
# top            NaN          NaN  MISCELLANEOUS HEALTH MEDICAL PROFESSIONS
# freq           NaN          NaN                                         1
# mean     87.000000  3879.815029                                       NaN
# std      50.084928  1687.753140                                       NaN
# min       1.000000  1100.000000                                       NaN
# 25%      44.000000  2403.000000                                       NaN
# 50%      87.000000  3608.000000                                       NaN
# 75%     130.000000  5503.000000                                       NaN
# max     173.000000  6403.000000                                       NaN
#
#                 Total            Men          Women Major_category  \
# ...

# %%
#drop data
raw_data_count = len(recent_grads.index) #count before

#drop all NA
recent_grads = recent_grads.dropna(axis=0)
cleaned_data_count = len(recent_grads.index) #count after

print(raw_data_count - cleaned_data_count)
# Out:
# 1

# %% [markdown]
# Scatter plots

# %%
ax = recent_grads.plot(x='Sample_size', y='Employed', kind='scatter')
ax.set_title('Employed vs. Sample_size')

# %%
recent_grads.plot(x='Sample_size',
                  y = 'Median',
                  kind = 'scatter', 
                  title = 'Sample Size vs. Median')

# %%
recent_grads.plot(x='Sample_size',
                  y = 'Unemployment_rate',
                  kind = 'scatter', 
                  title = 'Sample Size vs. Unemployment Rate')

# %%
recent_grads.plot(x='Full_time',
                  y = 'Median',
                  kind = 'scatter', 
                  title = 'Full_time vs. Median')

# %%
recent_grads.plot(x='ShareWomen',
                  y='Unemployment_rate',
                  kind = 'scatter', 
                  title='ShareWomen vs. Unemployment_rate')

# %%
recent_grads.plot(x='Men',
                  y='Median',
                  kind = 'scatter', 
                  title='Men vs. Median')

# %%
recent_grads.plot(x='Women',
                  y='Median',
                  kind = 'scatter', 
                  title='Women vs. Median')

# %% [markdown]
# Histograms

# %%
recent_grads['Sample_size'].hist(bins=25, range=(0,5000))

# %%
recent_grads['Sample_size'].hist(bins=25)

# %%
recent_grads['Median'].hist(bins=25)

# %%
recent_grads['Employed'].hist(bins=25)

# %%
recent_grads['Full_time'].hist(bins=25)

# %%
recent_grads['ShareWomen'].hist(bins=25)

# %%
recent_grads['Unemployment_rate'].hist(bins=25)

# %%
recent_grads['Men'].hist(bins=25)

# %%
recent_grads['Women'].hist(bins=25)

# %% [markdown]
# Scatter Matrix

# %%
pd.plotting.scatter_matrix(recent_grads[['Women', 'Men']], figsize = (10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0c726bbc88>,
# ...
#       dtype=object)

# %%
pd.plotting.scatter_matrix(recent_grads[['Sample_size','Median']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0c724a5080>,
# ...
#       dtype=object)

# %%
pd.plotting.scatter_matrix(recent_grads[['Sample_size','Median', 'Unemployment_rate']], 
                          figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0c7235ce10>,
# ...
#       dtype=object)

# %% [markdown]
# Barplots

# %%
recent_grads[:5]['Women'].plot(kind='bar')

# %%
recent_grads[:5].plot.bar(x='Major', y='Women')

# %%
first_and_last_ten = pd.concat([recent_grads[:10], recent_grads[-10:]])
first_and_last_ten.plot.bar(x='Major', y='ShareWomen')

# %%
first_and_last_ten.plot.bar(x='Major', y='Unemployment_rate')
